# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from rich.console import Console
from rich.panel import Panel
from rich.markdown import Markdown

load_dotenv("key.env")
api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(
    api_key=api_key,
    base_url="https://foundation-models.api.cloud.ru/v1"
)

console = Console()

memories = [
    {"role": "system",
     "content": "Ты помощник, всегда готовый всё объяснить."},
]

def respond_to_user(user_input):
    memories.append({"role": "user", "content": user_input})
    response = client.chat.completions.create(
        model="ai-sage/GigaChat3-10B-A1.8B",
        messages=memories
    )
    assistant_message = response.choices[0].message.content
    memories.append
    ({
            "role": "assistant",
            "content": assistant_message
    })
    return assistant_message

def letsbegin():
    console.print(Panel(
        "[bold green]Приветствую![/bold green]"
        "Commands: /exit to quit, /clear to clear history. If the message begins with /system, then it is a system message.",
        title="Чат с моделькой",
        subtitle="Стартуем!"
        ))
    
    while True:
        
        user_input = console.input("[bold blue]Вы:[/bold blue] ")
        print(user_input)
        
        if user_input.lower() == "/exit":
            console.print("[bold red]Выход из чата. Пока![/bold red]")
            break
        
        elif user_input.lower() == "/clear":
            uno = memories[0]
            memories.clear()
            memories.append(uno)
            console.print("[bold red]История очищена.[/bold red]")
            continue
        
        #role change
        elif user_input.lower().startswith("/system"):
            system_message = user_input[len("/system"):].strip()
            memories.append({"role": "system", "content": system_message})
            console.print("[bold red]Роль изменена.[/bold red]")
            continue
        
        memories.append({"role": "user", "content": user_input})
        assistant_message = respond_to_user(user_input)
        
        md = Markdown(assistant_message)
        console.print(Panel(md, title="[bold green]MODEL HAS SPOKEN...:[/bold green]"))

# %%
letsbegin()
# Out:
# ╭──────────────────────────────────────────────── Чат с моделькой ────────────────────────────────────────────────╮
# │ Приветствую!Commands: /exit to quit, /clear to clear history. If the message begins with /system, then it is a  │
# │ system message.                                                                                                 │
# ╰─────────────────────────────────────────────────── Стартуем! ───────────────────────────────────────────────────╯
# Вы:
# почему солнце такого цвета?
# ╭───────────────────────────────────────────── MODEL HAS SPOKEN...: ──────────────────────────────────────────────╮
# │ Солнечный свет кажется нам жёлтым или золотистым, как он становится после прохождения через атмосферу Земли. На │
# │ самом деле он состоит из всех цветов спектра. Наша воображение только накладывает цвет на волну постоянной      │
# │ длины. При этом зритель воспринимает свет именно той длины волны, которая соответствует цвету, а затем мозг     │
# │ дополняет остальные цвета, которых на самом деле нет. Особенность нашей двойной радужной системы зрения         │
# │ заключается в том, что мозг не всегда может правильно разделить, когда количество света для восприятия той или  │
# │ иной длины волны уменьшилось из-за облачности или тумана, а когда цвет изменяется из-за другого стимула, такого │
# │ как светящимся объектом, например, солнцем.                                                                     │
# │                                                                                                                 │
# │ Важно также понимать, что солнце — это звезда, а не планета. Оно рождается, как и все звезды на ранних этапах   │
# │ своего развития, из облака, состоящего преимущественно из газообразного водорода и гелия, земного               │
# │ происхождения. Его гравитация притягивает эти вещества ближе, создаёт давление, производит огромное количество  │
# │ энергии, и так далее. Нагревичная реакция превращает водород в гелий, а когда водород полностью выгорает, ядро  │
# │ начинает сжиматься. После этого из ядра выходит энергия. Энергия реакции становится больше и больше, давление   │
# │ увеличивается в ядре и звезда начинает расширятся. Энергия звезды начинает перегреваться, и скорее всего она    │
# │ превратится в красный гигант. Всё это происходит примерно спустя много, много миллиардов лет. Ни одного из тех  │
# │ звёзд или звёзд, которые когда-либо рождались остались, а цвет солнца может быть белым или сине-белым, но когда │
# │ он появляется над горизонтом или в тумане, он будет восприниматься человеческим зрением как жёлтый.             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Вы:
# /clear
# История очищена.
# Вы:
# Кто такой Лагранж?
# ╭───────────────────────────────────────────── MODEL HAS SPOKEN...: ──────────────────────────────────────────────╮
# │ Имя Лагранж, вероятно, отсылает к имени выдающегося французского математика Жозефа-Луи Лагранжа. Он был         │
# │ пионерами математического анализа, механики и математической физики. Его труды заложили основу для              │
# │ фундаментальных открытий в этих областях.                                                                       │
# │                                                                                                                 │
# │                                               Жозеф-Луи Лагранжа                                                │
# │                                                                                                                 │
# │  • Родился: 25 января 1736 года, в Турине, Италия.                                                              │
# │  • Смерть: 10 апреля 1813 года, Париж, Франция.                                                                 │
# │  • Университетская профессура: Французский университетский профессор математики и руководитель кафедры физики.  │
# │                                                                                                                 │
# │                                              Основные достижения:                                               │
# │                                                                                                                 │
# │  • Лагранж-Метод в математическом анализе: Вёл разработку метода вариационных задач, которые лежат в основе     │
# │    многих областей математики, таких как аналитическая механика и дифференциальные уравнения.                   │
# │  • Лагранж-модель в физической механике: Лагранжев формулировка механики Эйлера-Лагранжа (Lagrangian            │
# │    mechanics), где введена фундаментальная роль уравнения Гаусса-Лагранжа, ключевое уравнение в теории вариаций │
# │    и дифференциальных уравнениях.                                                                               │
# │  • Гидродинамика Лагранжа: Предложил новые подходы к пониманию динамики воды и газов.                           │
# │                                                                                                                 │
# │                                         Лагранж и математические задачи                                         │
# │                                                                                                                 │
# │  • Разработал вариационные методы, которые применяются в решении различных типов оптимизационных задач, в том   │
# │    числе задач принятия решений во многих областях, включая физиология и экономика.                             │
# │  • Ввел функции Лагранжа, пригодные для описания самок проявления степеней свободы в системах.                  │
# │                                                                                                                 │
# │                                              Историческое значение                                              │
# │                                                                                                                 │
# │ Лагранж внес значительный вклад к математической науке через серии эссе, аналитических работ и учебников,       │
# │ которые предложили революционные подходы к изучению математических проблем. Его работы продолжают активно       │
# │ использоваться и изучаются в различных сферах науки и инженерии.                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Вы:
# А в чём суть его метода?
# ╭───────────────────────────────────────────── MODEL HAS SPOKEN...: ──────────────────────────────────────────────╮
# │ Жозеф Луи Лагранж (1736–1813) — французский математик и механик, автор многочисленных работ по чистой и         │
# │ прикладной математике. В математике Ж. Лагранжа главным образом называют создателем вариационного исчисления.   │
# │                                                                                                                 │
# │ Метод множителей Лагранжа является методом, используемым в математике для поиска локального минимума или        │
# │ максимума функционалов. Это один из самых мощных методов оптимизации, содержащий в себе адаптивные свойства     │
# │ производных и закреплённые границы. Что само по себе делает переменную зависимой, а вторую, относительно её,    │
# │ независимой.                                                                                                    │
# │                                                                                                                 │
# │ Метод Лагранжа предназначен для решения задач оптимизации. Использовать этот метод удобно для задач, в которых  │
# │ функция, которую необходимо оптимизировать, зависит от нескольких аргументов, а также когда накладываются       │
# │ условия на эти аргументы. Степень этих условий равна числу не фиксированных переменных и, соответственно, числу │
# │ помогающих переменных.                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Вы:
# /clear
# История очищена.
# Вы:
# Кто такой император человечества из вселенной warhammer 40000
# ╭───────────────────────────────────────────── MODEL HAS SPOKEN...: ──────────────────────────────────────────────╮
# │ Император человечества, или просто «Император» (англ. The Emperor), является основным и самым могущественным    │
# │ персонажем вселенной Warhammer 40,000. Он представляет собой величайшего лидера человечества и его главного     │
# │ защитника в противостоянии силам хаоса, тёмных божеств и других межгалактических угроз. Император является      │
# │ существом из плоти и крови.                                                                                     │
# │                                                                                                                 │
# │ По своей природе Император является сверхчеловеческим существом, которое использовало свои огромные магические  │
# │ способности для преобразования галактику в унитарное государство с ярчайшим примером распространения гегемонии. │
# │ Это привело человечество к эпохе великих открытий [где-то даже «золотой век» человечества], которую научно      │
# │ назвали Эпоха Разделения. Его власть, возможно, была слегка ограничена расовой энергией и генетическим          │
# │ наследием человечества в целом, что делало его не всеведущим, но почти всевластным. Согласно некоторым версиям, │
# │ он был акрогефаликлом (близким к двум сотням метров высотой), хотя в юности он не выглядел особенно выдающимся  │
# │ в физическом плане.                                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Вы:
# /exit
# Выход из чата. Пока!
